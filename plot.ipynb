# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
t = [0.01, 0.1, 0.2, 0.45, 1.0, 3.0, 5.0, 'Inf']

AAP_teacher = [0.3950638591646531, 6.51415257162582, 17.9299275112185, 39.19899896444598, 45.858819468415604, 46.5735243355195, 46.580600621332415, 46.580600621332415]
AAP_baseline = [0.5044874007594062, 21.25698998964446, 35.23351743182603, 42.89955125992406, 45.196237487055576, 46.10010355540214, 46.244908526061444, 46.30100103555402]
AAP_kd = [0.12478425957887469, 10.508111839834312, 28.040041422160858, 43.537279944770454, 46.1406627545737, 46.481705212288574, 46.483431135657575, 46.483431135657575]

AJS_teacher = [1, 1, 1, 1, 1, 1, 1, 1]
AJS_baseline = [0.007676249650705986, 0.11517845490113895, 0.3173076134079782, 0.7246236459935181, 0.873334279417462, 0.9016587657069625, 0.9043634715647618, 0.9053362961220071]
AJS_kd = [0.009981590150730643, 0.2391673841852927, 0.42108840195124647, 0.7803509021546663, 0.9084854382177124, 0.9227710174814774, 0.9228713490921473, 0.9228713490921473]

f = plt.figure(figsize=(6,4))
plt.plot(t, AAP_teacher, label='Teacher', color='blue')
plt.plot(t, AAP_baseline, label='Student (Baseline)', color='red')
plt.plot(t, AAP_kd, label='Student (KD)', color='orange')
plt.xlabel('Distance Threshold')
plt.ylabel('Average Active Patches')
plt.legend()
plt.show()

f = plt.figure(figsize=(6,4))
plt.plot(t, AJS_teacher, label='Teacher', color='blue')
plt.plot(t, AJS_baseline, label='Student (Baseline)', color='red')
plt.plot(t, AJS_kd, label='Student (KD)', color='orange')
plt.xlabel('Distance Threshold')
plt.ylabel('Average Jaccard Similarity (with Teacher)')
plt.legend()
plt.show()
